# %%
import os
from mtcnn.mtcnn import MTCNN
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf

# %%
import keras

# %%
#keras.__version__

# %%
img = plt.imread('./0_origin/PF145953.jpg')

# %%
img.shape
# Out:
# (280, 218, 4)

# %%
plt.imshow(img)

# %%
detector = MTCNN()
# Out:
# WARNING:tensorflow:From /home/caitech/anaconda3/envs/yu4/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/caitech/anaconda3/envs/yu4/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
faces = detector.detect_faces(img)

# %%
type(faces)
# Out:
# list

# %%
len(faces)
# Out:
# 5

# %%
faces
# Out:
# [{'box': [108, 463, 177, 231],
#   'confidence': 0.999945878982544,
#   'keypoints': {'left_eye': (171, 543),
#    'right_eye': (248, 564),
#    'nose': (201, 605),
#    'mouth_left': (159, 638),
#    'mouth_right': (211, 651)}},
#  {'box': [249, 99, 174, 236],
#   'confidence': 0.9999411106109619,
#   'keypoints': {'left_eye': (298, 178),
#    'right_eye': (377, 179),
#    'nose': (337, 228),
#    'mouth_left': (295, 270),
#    'mouth_right': (369, 271)}},
#  {'box': [51, 179, 170, 219],
#   'confidence': 0.9998134970664978,
#   'keypoints': {'left_eye': (127, 254),
#    'right_eye': (192, 292),
#    'nose': (151, 302),
#    'mouth_left': (95, 332),
#    'mouth_right': (145, 359)}},
#  {'box': [450, 513, 162, 228],
#   'confidence': 0.9996707439422607,
#   'keypoints': {'left_eye': (510, 602),
#    'right_eye': (583, 598),
#    'nose': (560, 655),
#    'mouth_left': (517, 689),
#    'mouth_right': (576, 684)}},
#  {'box': [431, 111, 204, 219],
#   'confidence': 0.999440610408783,
# ...

# %%
for face in faces:
    print(face)
# Out:
# {'box': [108, 463, 177, 231], 'confidence': 0.999945878982544, 'keypoints': {'left_eye': (171, 543), 'right_eye': (248, 564), 'nose': (201, 605), 'mouth_left': (159, 638), 'mouth_right': (211, 651)}}
# {'box': [249, 99, 174, 236], 'confidence': 0.9999411106109619, 'keypoints': {'left_eye': (298, 178), 'right_eye': (377, 179), 'nose': (337, 228), 'mouth_left': (295, 270), 'mouth_right': (369, 271)}}
# {'box': [51, 179, 170, 219], 'confidence': 0.9998134970664978, 'keypoints': {'left_eye': (127, 254), 'right_eye': (192, 292), 'nose': (151, 302), 'mouth_left': (95, 332), 'mouth_right': (145, 359)}}
# {'box': [450, 513, 162, 228], 'confidence': 0.9996707439422607, 'keypoints': {'left_eye': (510, 602), 'right_eye': (583, 598), 'nose': (560, 655), 'mouth_left': (517, 689), 'mouth_right': (576, 684)}}
# ...

# %%
len(faces)
# Out:
# 5

# %%
path = './0/'

# %%
#filename = 'PF154694.jpg'

# %%
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = plt.imread(filename)
	# plot the image
	plt.imshow(data)
	# get the context for drawing boxes
	ax = plt.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='yellow')
		# draw the box
		ax.add_patch(rect)
	# show the plot
	plt.show()

# %%
#filename = '/home/caitech/Desktop/yujung/0/PF154694.jpg'

filename = './0_origin/PF132599.jpg'
# load image from file
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = '/home/caitech/Desktop/yujung/0/PF155251.jpg'

# %%
data = plt.imread(filename)
# plot the image
plt.imshow(data)
# get the context for drawing boxes
ax = plt.gca()
# plot each box
for result in faces:
    # get coordinates
    x, y, width, height = result['box']
    # create the shape
    rect = Rectangle((x, y), width, height, fill=False, color='yellow')
    # draw the box
    ax.add_patch(rect)
    # show the plot
plt.show()

# %%
plt.savefig('myfile.jpg')

# %%
for result in faces:
		# get coordinates
	x, y, width, height = result['box']
		# create the shape
	rect = Rectangle((x, y), width, height, fill=False, color='yellow')
		# draw the box
	ax.add_patch(rect)
	# show the plot
plt.show()

# %%
rect

# %%
plt.show()

# %%
import cv2

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img = plt.imread('./0/PF132599.jpg')

# %%
img2 = img[:,:,0:3]

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (280, 218, 4)

# %%
img.shape
# Out:
# (280, 218, 4)

# %%
cv2.imwrite('./faceimage.jpg',a)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-a623e32ab403> in <module>
# ----> 1 cv2.imwrite('./faceimage.jpg',a)
#
# error: OpenCV(4.3.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
os.getcwd()

# %% [markdown]
# DS_Store wldnrl
#
# find . -name "*.DS_Store" -type f -delete

# %%
files_0 = os.listdir('./0_origin/')
files_1 = os.listdir('./1_origin/')

# %%
len(files_1)
# Out:
# 1272

# %%
path_0 = './0_origin/'
path_1 = './1_origin/'

# %%
detector = MTCNN()

# %%
face_list_0 = []
face_list_1 = []
fail = []

# %%
for file in files_0:
    try:
        img = plt.imread(path_0+file)
        faces = detector.detect_faces(img[:,:,0:3])
        face_list_0.append(len(faces))
    except :
        fail.append(file)

# %%
len(fail)
# Out:
# 0

# %%
fail_1 = []

# %%
for file in files_1:
    try:
        img = plt.imread(path_1+file)
        faces = detector.detect_faces(img[:,:,0:3])
        face_list_1.append(len(faces))
    except:
        fail_1.append(file)

# %%
len(files_0)
# Out:
# 576

# %%
len(fail_1)
# Out:
# 0

# %%
len(face_list_1)
# Out:
# 1272

# %%
import pandas as pd
df_0 = pd.DataFrame()

# %%
df_0['filename'] = files_0

# %%
df_0['facecount'] = face_list_0

# %%
df_0.to_excel('0_origin_face.xlsx',index = False)

# %%
df_1 = pd.DataFrame()

# %%
df_1['filename'] = files_1

# %%
df_1['facecount'] = face_list_1

# %%
df_1.to_excel('1_origin_face.xlsx',index = False)

# %%
faces
